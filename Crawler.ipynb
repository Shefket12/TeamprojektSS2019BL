# %%
import requests
import pandas as pd
import json
import time
from pandas.io.json import json_normalize

df = pd.read_csv('http://www.openligadb.de/api/getmatchdata/bl1/2018/33')   #read the Data from the website
#df = df[['MatchID','Team1','Team2']]
df.head()                                                                   #print the head of the CSV 



#df['API_response'] = df.apply(get_reverse_geocode_data,axis=1)
#df['API_response'].head()
        

##r = requests.get('http://www.openligadb.de/api/getmatchdata/bl1/2018/30')
##r.json()
# Out:
# Empty DataFrame
# Columns: [[{"MatchID":51408, MatchDateTime:"2019-05-11T15:30:00", TimeZoneID:"W. Europe Standard Time", LeagueId:4276, LeagueName:"1. Fußball-Bundesliga 2018/2019", MatchDateTimeUTC:"2019-05-11T13:30:00Z", Group:{"GroupName":"33. Spieltag", GroupOrderID:33, GroupID:31807}, Team1:{"TeamId":123, TeamName:"TSG 1899 Hoffenheim", ShortName:"Hoffenheim", TeamIconUrl:"https://upload.wikimedia.org/wikipedia/commons/6/64/TSG_Logo-Standard_4c.png", TeamGroupName:null}, Team2:{"TeamId":134, TeamName:"Werder Bremen", ShortName:"Bremen", TeamIconUrl:"https://upload.wikimedia.org/wikipedia/commons/thumb/b/be/SV-Werder-Bremen-Logo.svg/681px-SV-Werder-Bremen-Logo.svg.png", TeamGroupName:null}.1, LastUpdateDateTime:"2018-06-30T16:55:59.157", MatchIsFinished:false, MatchResults:[], Goals:[], Location:null, NumberOfViewers:null}, {"MatchID":51409, MatchDateTime:"2019-05-11T15:30:00".1, TimeZoneID:"W. Europe Standard Time".1, LeagueId:4276.1, LeagueName:"1. Fußball-Bundesliga 2018/2019".1, MatchDateTimeUTC:"2019-05-11T13:30:00Z".1, Group:{"GroupName":"33. Spieltag".1, GroupOrderID:33.1, GroupID:31807}.1, Team1:{"TeamId":7, TeamName:"Borussia Dortmund", ShortName:"BVB", TeamIconUrl:"https://upload.wikimedia.org/wikipedia/commons/thumb/6/67/Borussia_Dortmund_logo.svg/240px-Borussia_Dortmund_logo.svg.png", TeamGroupName:null}.2, Team2:{"TeamId":185, TeamName:"Fortuna Düsseldorf", ShortName:"Düsseldorf", TeamIconUrl:"https://upload.wikimedia.org/wikipedia/commons/thumb/9/94/Fortuna_D%C3%BCsseldorf.svg/150px-Fortuna_D%C3%BCsseldorf.svg.png", TeamGroupName:null}.3, LastUpdateDateTime:"2018-06-30T16:56:19.457", MatchIsFinished:false.1, MatchResults:[].1, Goals:[].1, Location:null.1, NumberOfViewers:null}.1, {"MatchID":51410, MatchDateTime:"2019-05-11T15:30:00".2, TimeZoneID:"W. Europe Standard Time".2, LeagueId:4276.2, LeagueName:"1. Fußball-Bundesliga 2018/2019".2, MatchDateTimeUTC:"2019-05-11T13:30:00Z".2, Group:{"GroupName":"33. Spieltag".2, GroupOrderID:33.2, GroupID:31807}.2, Team1:{"TeamId":6, TeamName:"Bayer Leverkusen", ShortName:"Leverkusen", TeamIconUrl:"https://upload.wikimedia.org/wikipedia/de/thumb/f/f7/Bayer_Leverkusen_Logo.svg/1280px-Bayer_Leverkusen_Logo.svg.png", TeamGroupName:null}.4, Team2:{"TeamId":9, TeamName:"FC Schalke 04", ShortName:"Schalke", TeamIconUrl:"https://upload.wikimedia.org/wikipedia/commons/thumb/6/6d/FC_Schalke_04_Logo.svg/1024px-FC_Schalke_04_Logo.svg.png", TeamGroupName:null}.5, LastUpdateDateTime:"2018-06-30T16:56:36.54", MatchIsFinished:false.2, MatchResults:[].2, Goals:[].2, Location:null.2, NumberOfViewers:null}.2, {"MatchID":51411, MatchDateTime:"2019-05-11T15:30:00".3, TimeZoneID:"W. Europe Standard Time".3, LeagueId:4276.3, LeagueName:"1. Fußball-Bundesliga 2018/2019".3, MatchDateTimeUTC:"2019-05-11T13:30:00Z".3, Group:{"GroupName":"33. Spieltag".3, GroupOrderID:33.3, GroupID:31807}.3, Team1:{"TeamId":1635, TeamName:"RB Leipzig", ShortName:"RBL Leipzig", TeamIconUrl:"https://upload.wikimedia.org/wikipedia/en/thumb/0/04/RB_Leipzig_2014_logo.svg/20px-RB_Leipzig_2014_logo.svg.png", TeamGroupName:null}.6, Team2:{"TeamId":40, TeamName:"FC Bayern", ShortName:"FCB", TeamIconUrl:"https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Logo_FC_Bayern_M%C3%BCnchen_%282002%E2%80%932017%29.svg/240px-Logo_FC_Bayern_M%C3%BCnchen_%282002%E2%80%932017%29.svg.png", TeamGroupName:null}.7, LastUpdateDateTime:"2018-06-30T16:57:01.57", MatchIsFinished:false.3, MatchResults:[].3, Goals:[].3, Location:null.3, NumberOfViewers:null}.3, ...]
# Index: []
#
# [0 rows x 227 columns]

# %%
r = requests.get('http://www.openligadb.de/api/getmatchdata/bl1/2018/30')
#r.json()
#k = r.json()            #safe as JSON
#df = pd.DataFrame(k)    #safe as DataFrame
#df = df[['Team1']]      #keep only "Team1"

#df.head()

# %%
k
# Out:
# [{'MatchID': 51381,
#   'MatchDateTime': '2019-04-20T15:30:00',
#   'TimeZoneID': 'W. Europe Standard Time',
#   'LeagueId': 4276,
#   'LeagueName': '1. Fußball-Bundesliga 2018/2019',
#   'MatchDateTimeUTC': '2019-04-20T13:30:00Z',
#   'Group': {'GroupName': '30. Spieltag', 'GroupOrderID': 30, 'GroupID': 31804},
#   'Team1': {'TeamId': 40,
#    'TeamName': 'FC Bayern',
#    'ShortName': 'FCB',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Logo_FC_Bayern_M%C3%BCnchen_%282002%E2%80%932017%29.svg/240px-Logo_FC_Bayern_M%C3%BCnchen_%282002%E2%80%932017%29.svg.png',
#    'TeamGroupName': None},
#   'Team2': {'TeamId': 134,
#    'TeamName': 'Werder Bremen',
#    'ShortName': 'Bremen',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/be/SV-Werder-Bremen-Logo.svg/681px-SV-Werder-Bremen-Logo.svg.png',
#    'TeamGroupName': None},
#   'LastUpdateDateTime': '2019-04-20T17:23:13.5',
#   'MatchIsFinished': True,
#   'MatchResults': [{'ResultID': 86841,
#     'ResultName': 'Endergebnis',
#     'PointsTeam1': 1,
#     'PointsTeam2': 0,
#     'ResultOrderID': 2,
#     'ResultTypeID': 2,
#     'ResultDescription': 'Ergebnis nach Ende der offiziellen Spielzeit'},
#    {'ResultID': 86842,
#     'ResultName': 'Halbzeit',
#     'PointsTeam1': 0,
#     'PointsTeam2': 0,
#     'ResultOrderID': 1,
#     'ResultTypeID': 1,
#     'ResultDescription': 'Zwischenstand zur Halbzeit'}],
#   'Goals': [{'GoalID': 77129,
#     'ScoreTeam1': 1,
#     'ScoreTeam2': 0,
#     'MatchMinute': 76,
#     'GoalGetterID': 16184,
#     'GoalGetterName': 'Niklas Süle',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None}],
#   'Location': None,
#   'NumberOfViewers': None},
#  {'MatchID': 51383,
#   'MatchDateTime': '2019-04-20T15:30:00',
#   'TimeZoneID': 'W. Europe Standard Time',
#   'LeagueId': 4276,
#   'LeagueName': '1. Fußball-Bundesliga 2018/2019',
#   'MatchDateTimeUTC': '2019-04-20T13:30:00Z',
#   'Group': {'GroupName': '30. Spieltag', 'GroupOrderID': 30, 'GroupID': 31804},
#   'Team1': {'TeamId': 6,
#    'TeamName': 'Bayer Leverkusen',
#    'ShortName': 'Leverkusen',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/de/thumb/f/f7/Bayer_Leverkusen_Logo.svg/1280px-Bayer_Leverkusen_Logo.svg.png',
#    'TeamGroupName': None},
#   'Team2': {'TeamId': 79,
#    'TeamName': '1. FC Nürnberg',
#    'ShortName': 'Nürnberg',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/1._FC_Nürnberg_logo.svg/1024px-1._FC_Nürnberg_logo.svg.png',
#    'TeamGroupName': None},
#   'LastUpdateDateTime': '2019-04-20T17:23:14.907',
#   'MatchIsFinished': True,
#   'MatchResults': [{'ResultID': 86835,
#     'ResultName': 'Endergebnis',
#     'PointsTeam1': 2,
#     'PointsTeam2': 0,
#     'ResultOrderID': 2,
#     'ResultTypeID': 2,
#     'ResultDescription': 'Ergebnis nach Ende der offiziellen Spielzeit'},
#    {'ResultID': 86836,
#     'ResultName': 'Halbzeit',
#     'PointsTeam1': 0,
#     'PointsTeam2': 0,
#     'ResultOrderID': 1,
#     'ResultTypeID': 1,
#     'ResultDescription': 'Zwischenstand zur Halbzeit'}],
#   'Goals': [{'GoalID': 77126,
#     'ScoreTeam1': 1,
#     'ScoreTeam2': 0,
#     'MatchMinute': 61,
#     'GoalGetterID': 16277,
#     'GoalGetterName': 'Alario',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77130,
#     'ScoreTeam1': 2,
#     'ScoreTeam2': 0,
#     'MatchMinute': 87,
#     'GoalGetterID': 16260,
#     'GoalGetterName': 'Kevin Volland\r\n',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None}],
#   'Location': {'LocationID': 28,
#    'LocationCity': 'Leverkusen',
#    'LocationStadium': 'BayArena'},
#   'NumberOfViewers': None},
#  {'MatchID': 51386,
#   'MatchDateTime': '2019-04-20T15:30:00',
#   'TimeZoneID': 'W. Europe Standard Time',
#   'LeagueId': 4276,
#   'LeagueName': '1. Fußball-Bundesliga 2018/2019',
#   'MatchDateTimeUTC': '2019-04-20T13:30:00Z',
#   'Group': {'GroupName': '30. Spieltag', 'GroupOrderID': 30, 'GroupID': 31804},
#   'Team1': {'TeamId': 95,
#    'TeamName': 'FC Augsburg',
#    'ShortName': 'Augsburg',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/de/thumb/b/b5/Logo_FC_Augsburg.svg/785px-Logo_FC_Augsburg.svg.png',
#    'TeamGroupName': None},
#   'Team2': {'TeamId': 16,
#    'TeamName': 'VfB Stuttgart',
#    'ShortName': 'Stuttgart',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/eb/VfB_Stuttgart_1893_Logo.svg/921px-VfB_Stuttgart_1893_Logo.svg.png',
#    'TeamGroupName': None},
#   'LastUpdateDateTime': '2019-04-20T17:23:15.303',
#   'MatchIsFinished': True,
#   'MatchResults': [{'ResultID': 86837,
#     'ResultName': 'Endergebnis',
#     'PointsTeam1': 6,
#     'PointsTeam2': 0,
#     'ResultOrderID': 2,
#     'ResultTypeID': 2,
#     'ResultDescription': 'Ergebnis nach Ende der offiziellen Spielzeit'},
#    {'ResultID': 86838,
#     'ResultName': 'Halbzeit',
#     'PointsTeam1': 3,
#     'PointsTeam2': 0,
#     'ResultOrderID': 1,
#     'ResultTypeID': 1,
#     'ResultDescription': 'Zwischenstand zur Halbzeit'}],
#   'Goals': [{'GoalID': 77099,
#     'ScoreTeam1': 1,
#     'ScoreTeam2': 0,
#     'MatchMinute': 11,
#     'GoalGetterID': 785,
#     'GoalGetterName': 'Khedira',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77100,
#     'ScoreTeam1': 2,
#     'ScoreTeam2': 0,
#     'MatchMinute': 20,
#     'GoalGetterID': 16036,
#     'GoalGetterName': 'Andre Hahn',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77102,
#     'ScoreTeam1': 3,
#     'ScoreTeam2': 0,
#     'MatchMinute': 29,
#     'GoalGetterID': 16688,
#     'GoalGetterName': 'Max, Philipp',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77117,
#     'ScoreTeam1': 4,
#     'ScoreTeam2': 0,
#     'MatchMinute': 53,
#     'GoalGetterID': 15376,
#     'GoalGetterName': 'Richter, Marco',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77122,
#     'ScoreTeam1': 5,
#     'ScoreTeam2': 0,
#     'MatchMinute': 59,
#     'GoalGetterID': 16688,
#     'GoalGetterName': 'Max, Philipp',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77128,
#     'ScoreTeam1': 6,
#     'ScoreTeam2': 0,
#     'MatchMinute': 68,
#     'GoalGetterID': 15376,
#     'GoalGetterName': 'Richter, Marco',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None}],
#   'Location': None,
#   'NumberOfViewers': None},
#  {'MatchID': 51388,
#   'MatchDateTime': '2019-04-20T15:30:00',
#   'TimeZoneID': 'W. Europe Standard Time',
#   'LeagueId': 4276,
#   'LeagueName': '1. Fußball-Bundesliga 2018/2019',
#   'MatchDateTimeUTC': '2019-04-20T13:30:00Z',
#   'Group': {'GroupName': '30. Spieltag', 'GroupOrderID': 30, 'GroupID': 31804},
#   'Team1': {'TeamId': 81,
#    'TeamName': '1. FSV Mainz 05',
#    'ShortName': 'Mainz 05',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Logo_Mainz_05.svg/1099px-Logo_Mainz_05.svg.png',
#    'TeamGroupName': None},
#   'Team2': {'TeamId': 185,
#    'TeamName': 'Fortuna Düsseldorf',
#    'ShortName': 'Düsseldorf',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/94/Fortuna_D%C3%BCsseldorf.svg/150px-Fortuna_D%C3%BCsseldorf.svg.png',
#    'TeamGroupName': None},
#   'LastUpdateDateTime': '2019-04-20T17:23:17.497',
#   'MatchIsFinished': True,
#   'MatchResults': [{'ResultID': 86839,
#     'ResultName': 'Endergebnis',
#     'PointsTeam1': 3,
#     'PointsTeam2': 1,
#     'ResultOrderID': 2,
#     'ResultTypeID': 2,
#     'ResultDescription': 'Ergebnis nach Ende der offiziellen Spielzeit'},
#    {'ResultID': 86840,
#     'ResultName': 'Halbzeit',
#     'PointsTeam1': 1,
#     'PointsTeam2': 1,
#     'ResultOrderID': 1,
#     'ResultTypeID': 1,
#     'ResultDescription': 'Zwischenstand zur Halbzeit'}],
#   'Goals': [{'GoalID': 77098,
#     'ScoreTeam1': 1,
#     'ScoreTeam2': 0,
#     'MatchMinute': 2,
#     'GoalGetterID': 16904,
#     'GoalGetterName': 'J.-P.Mateta',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77101,
#     'ScoreTeam1': 1,
#     'ScoreTeam2': 1,
#     'MatchMinute': 19,
#     'GoalGetterID': 16913,
#     'GoalGetterName': 'Lukebakio',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77127,
#     'ScoreTeam1': 2,
#     'ScoreTeam2': 1,
#     'MatchMinute': 67,
#     'GoalGetterID': 16203,
#     'GoalGetterName': 'Karim  Onisiwo',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77131,
#     'ScoreTeam1': 3,
#     'ScoreTeam2': 1,
#     'MatchMinute': 87,
#     'GoalGetterID': 16904,
#     'GoalGetterName': 'J.-P.Mateta',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None}],
#   'Location': None,
#   'NumberOfViewers': None},
#  {'MatchID': 51384,
#   'MatchDateTime': '2019-04-20T18:30:00',
#   'TimeZoneID': 'W. Europe Standard Time',
#   'LeagueId': 4276,
#   'LeagueName': '1. Fußball-Bundesliga 2018/2019',
#   'MatchDateTimeUTC': '2019-04-20T16:30:00Z',
#   'Group': {'GroupName': '30. Spieltag', 'GroupOrderID': 30, 'GroupID': 31804},
#   'Team1': {'TeamId': 87,
#    'TeamName': 'Borussia Mönchengladbach',
#    'ShortName': "M'gladbach",
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Borussia_Mönchengladbach_logo.svg/630px-Borussia_Mönchengladbach_logo.svg.png',
#    'TeamGroupName': None},
#   'Team2': {'TeamId': 1635,
#    'TeamName': 'RB Leipzig',
#    'ShortName': 'RBL Leipzig',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/en/thumb/0/04/RB_Leipzig_2014_logo.svg/20px-RB_Leipzig_2014_logo.svg.png',
#    'TeamGroupName': None},
#   'LastUpdateDateTime': '2019-04-20T20:24:23.747',
#   'MatchIsFinished': True,
#   'MatchResults': [{'ResultID': 86858,
#     'ResultName': 'Endergebnis',
#     'PointsTeam1': 1,
#     'PointsTeam2': 2,
#     'ResultOrderID': 2,
#     'ResultTypeID': 2,
#     'ResultDescription': 'Ergebnis nach Ende der offiziellen Spielzeit'},
#    {'ResultID': 86859,
#     'ResultName': 'Halbzeit',
#     'PointsTeam1': 0,
#     'PointsTeam2': 1,
#     'ResultOrderID': 1,
#     'ResultTypeID': 1,
#     'ResultDescription': 'Zwischenstand zur Halbzeit'}],
#   'Goals': [{'GoalID': 77132,
#     'ScoreTeam1': 0,
#     'ScoreTeam2': 1,
#     'MatchMinute': 17,
#     'GoalGetterID': 6761,
#     'GoalGetterName': 'Halstenberg',
#     'IsPenalty': True,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77133,
#     'ScoreTeam1': 0,
#     'ScoreTeam2': 2,
#     'MatchMinute': 53,
#     'GoalGetterID': 6761,
#     'GoalGetterName': 'Halstenberg',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77134,
#     'ScoreTeam1': 1,
#     'ScoreTeam2': 2,
#     'MatchMinute': 62,
#     'GoalGetterID': 16907,
#     'GoalGetterName': 'A.Plea',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None}],
#   'Location': None,
#   'NumberOfViewers': None},
#  {'MatchID': 51382,
#   'MatchDateTime': '2019-04-20T20:30:00',
#   'TimeZoneID': 'W. Europe Standard Time',
#   'LeagueId': 4276,
#   'LeagueName': '1. Fußball-Bundesliga 2018/2019',
#   'MatchDateTimeUTC': '2019-04-20T18:30:00Z',
#   'Group': {'GroupName': '30. Spieltag', 'GroupOrderID': 30, 'GroupID': 31804},
#   'Team1': {'TeamId': 9,
#    'TeamName': 'FC Schalke 04',
#    'ShortName': 'Schalke',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6d/FC_Schalke_04_Logo.svg/1024px-FC_Schalke_04_Logo.svg.png',
#    'TeamGroupName': None},
#   'Team2': {'TeamId': 123,
#    'TeamName': 'TSG 1899 Hoffenheim',
#    'ShortName': 'Hoffenheim',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/6/64/TSG_Logo-Standard_4c.png',
#    'TeamGroupName': None},
#   'LastUpdateDateTime': '2019-04-20T22:20:57.353',
#   'MatchIsFinished': True,
#   'MatchResults': [{'ResultID': 86860,
#     'ResultName': 'Endergebnis',
#     'PointsTeam1': 2,
#     'PointsTeam2': 5,
#     'ResultOrderID': 2,
#     'ResultTypeID': 2,
#     'ResultDescription': 'Ergebnis nach Ende der offiziellen Spielzeit'},
#    {'ResultID': 86861,
#     'ResultName': 'Halbzeit',
#     'PointsTeam1': 0,
#     'PointsTeam2': 2,
#     'ResultOrderID': 1,
#     'ResultTypeID': 1,
#     'ResultDescription': 'Zwischenstand zur Halbzeit'}],
#   'Goals': [{'GoalID': 77135,
#     'ScoreTeam1': 0,
#     'ScoreTeam2': 1,
#     'MatchMinute': 25,
#     'GoalGetterID': 7180,
#     'GoalGetterName': 'Belfodil',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77136,
#     'ScoreTeam1': 0,
#     'ScoreTeam2': 2,
#     'MatchMinute': 45,
#     'GoalGetterID': 16104,
#     'GoalGetterName': 'Andrej Kramaric',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77137,
#     'ScoreTeam1': 1,
#     'ScoreTeam2': 2,
#     'MatchMinute': 60,
#     'GoalGetterID': 14694,
#     'GoalGetterName': 'Caligiuri, Daniel',
#     'IsPenalty': True,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77138,
#     'ScoreTeam1': 1,
#     'ScoreTeam2': 3,
#     'MatchMinute': 65,
#     'GoalGetterID': 15841,
#     'GoalGetterName': 'Szalai, Adam',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77139,
#     'ScoreTeam1': 1,
#     'ScoreTeam2': 4,
#     'MatchMinute': 73,
#     'GoalGetterID': 16216,
#     'GoalGetterName': 'Nadiem Amiri',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77140,
#     'ScoreTeam1': 1,
#     'ScoreTeam2': 5,
#     'MatchMinute': 80,
#     'GoalGetterID': 7180,
#     'GoalGetterName': 'Belfodil',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77141,
#     'ScoreTeam1': 2,
#     'ScoreTeam2': 5,
#     'MatchMinute': 89,
#     'GoalGetterID': 15352,
#     'GoalGetterName': 'Burgstaller, Guido',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None}],
#   'Location': None,
#   'NumberOfViewers': None},
#  {'MatchID': 51387,
#   'MatchDateTime': '2019-04-21T15:30:00',
#   'TimeZoneID': 'W. Europe Standard Time',
#   'LeagueId': 4276,
#   'LeagueName': '1. Fußball-Bundesliga 2018/2019',
#   'MatchDateTimeUTC': '2019-04-21T13:30:00Z',
#   'Group': {'GroupName': '30. Spieltag', 'GroupOrderID': 30, 'GroupID': 31804},
#   'Team1': {'TeamId': 112,
#    'TeamName': 'SC Freiburg',
#    'ShortName': 'Freiburg',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/de/thumb/f/f1/SC-Freiburg_Logo-neu.svg/739px-SC-Freiburg_Logo-neu.svg.png',
#    'TeamGroupName': None},
#   'Team2': {'TeamId': 7,
#    'TeamName': 'Borussia Dortmund',
#    'ShortName': 'BVB',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/67/Borussia_Dortmund_logo.svg/240px-Borussia_Dortmund_logo.svg.png',
#    'TeamGroupName': None},
#   'LastUpdateDateTime': '2019-04-21T17:19:12.403',
#   'MatchIsFinished': True,
#   'MatchResults': [{'ResultID': 86862,
#     'ResultName': 'Endergebnis',
#     'PointsTeam1': 0,
#     'PointsTeam2': 4,
#     'ResultOrderID': 2,
#     'ResultTypeID': 2,
#     'ResultDescription': 'Ergebnis nach Ende der offiziellen Spielzeit'},
#    {'ResultID': 86863,
#     'ResultName': 'Halbzeit',
#     'PointsTeam1': 0,
#     'PointsTeam2': 1,
#     'ResultOrderID': 1,
#     'ResultTypeID': 1,
#     'ResultDescription': 'Zwischenstand zur Halbzeit'}],
#   'Goals': [{'GoalID': 77142,
#     'ScoreTeam1': 0,
#     'ScoreTeam2': 1,
#     'MatchMinute': 12,
#     'GoalGetterID': 16502,
#     'GoalGetterName': 'Sancho',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77159,
#     'ScoreTeam1': 0,
#     'ScoreTeam2': 2,
#     'MatchMinute': 54,
#     'GoalGetterID': 3426,
#     'GoalGetterName': 'Marco Reus',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77160,
#     'ScoreTeam1': 0,
#     'ScoreTeam2': 3,
#     'MatchMinute': 79,
#     'GoalGetterID': 12757,
#     'GoalGetterName': 'Götze',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77161,
#     'ScoreTeam1': 0,
#     'ScoreTeam2': 4,
#     'MatchMinute': 87,
#     'GoalGetterID': 16945,
#     'GoalGetterName': 'Alcacer',
#     'IsPenalty': True,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None}],
#   'Location': None,
#   'NumberOfViewers': None},
#  {'MatchID': 51385,
#   'MatchDateTime': '2019-04-21T18:00:00',
#   'TimeZoneID': 'W. Europe Standard Time',
#   'LeagueId': 4276,
#   'LeagueName': '1. Fußball-Bundesliga 2018/2019',
#   'MatchDateTimeUTC': '2019-04-21T16:00:00Z',
#   'Group': {'GroupName': '30. Spieltag', 'GroupOrderID': 30, 'GroupID': 31804},
#   'Team1': {'TeamId': 54,
#    'TeamName': 'Hertha BSC',
#    'ShortName': 'Hertha',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Hertha_BSC_Logo_2012.svg/2858px-Hertha_BSC_Logo_2012.svg.png',
#    'TeamGroupName': None},
#   'Team2': {'TeamId': 55,
#    'TeamName': 'Hannover 96',
#    'ShortName': 'Hannover',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Hannover_96_Logo.svg/1162px-Hannover_96_Logo.svg.png',
#    'TeamGroupName': None},
#   'LastUpdateDateTime': '2019-04-21T19:59:29.507',
#   'MatchIsFinished': True,
#   'MatchResults': [{'ResultID': 86878,
#     'ResultName': 'Endergebnis',
#     'PointsTeam1': 0,
#     'PointsTeam2': 0,
#     'ResultOrderID': 2,
#     'ResultTypeID': 2,
#     'ResultDescription': 'Ergebnis nach Ende der offiziellen Spielzeit'},
#    {'ResultID': 86879,
#     'ResultName': 'Halbzeit',
#     'PointsTeam1': 0,
#     'PointsTeam2': 0,
#     'ResultOrderID': 1,
#     'ResultTypeID': 1,
#     'ResultDescription': 'Zwischenstand zur Halbzeit'}],
#   'Goals': [],
#   'Location': None,
#   'NumberOfViewers': None},
#  {'MatchID': 51389,
#   'MatchDateTime': '2019-04-22T20:30:00',
#   'TimeZoneID': 'W. Europe Standard Time',
#   'LeagueId': 4276,
#   'LeagueName': '1. Fußball-Bundesliga 2018/2019',
#   'MatchDateTimeUTC': '2019-04-22T18:30:00Z',
#   'Group': {'GroupName': '30. Spieltag', 'GroupOrderID': 30, 'GroupID': 31804},
#   'Team1': {'TeamId': 131,
#    'TeamName': 'VfL Wolfsburg',
#    'ShortName': 'VfL Wolfsburg',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Logo-VfL-Wolfsburg.svg/1024px-Logo-VfL-Wolfsburg.svg.png',
#    'TeamGroupName': None},
#   'Team2': {'TeamId': 91,
#    'TeamName': 'Eintracht Frankfurt',
#    'ShortName': 'Frankfurt',
#    'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/04/Eintracht_Frankfurt_Logo.svg/1024px-Eintracht_Frankfurt_Logo.svg.png',
#    'TeamGroupName': None},
#   'LastUpdateDateTime': '2019-04-22T22:22:57.99',
#   'MatchIsFinished': True,
#   'MatchResults': [{'ResultID': 86880,
#     'ResultName': 'Endergebnis',
#     'PointsTeam1': 1,
#     'PointsTeam2': 1,
#     'ResultOrderID': 2,
#     'ResultTypeID': 2,
#     'ResultDescription': 'Ergebnis nach Ende der offiziellen Spielzeit'},
#    {'ResultID': 86881,
#     'ResultName': 'Halbzeit',
#     'PointsTeam1': 0,
#     'PointsTeam2': 0,
#     'ResultOrderID': 1,
#     'ResultTypeID': 1,
#     'ResultDescription': 'Zwischenstand zur Halbzeit'}],
#   'Goals': [{'GoalID': 77164,
#     'ScoreTeam1': 0,
#     'ScoreTeam2': 0,
#     'MatchMinute': None,
#     'GoalGetterID': 0,
#     'GoalGetterName': '',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77165,
#     'ScoreTeam1': 0,
#     'ScoreTeam2': 1,
#     'MatchMinute': 78,
#     'GoalGetterID': 17432,
#     'GoalGetterName': 'Guzman',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None},
#    {'GoalID': 77166,
#     'ScoreTeam1': 1,
#     'ScoreTeam2': 1,
#     'MatchMinute': 90,
#     'GoalGetterID': 14266,
#     'GoalGetterName': 'John Brooks Jr.',
#     'IsPenalty': False,
#     'IsOwnGoal': False,
#     'IsOvertime': False,
#     'Comment': None}],
#   'Location': {'LocationID': 1296,
#    'LocationCity': 'sorry',
#    'LocationStadium': None},
#   'NumberOfViewers': None}]

# %%
todos = json.loads(r.text)
counter = 0

Game = {}
Date = {}
Hometeam = {}
Awayteam = {}
GoalsHome = {}
GoalsAway = {}


## The todos has different tuples Like: [Team1:'Name','TeamID', 'ShortName']
# To get different values we save the lists in different vars and then go through the lists in the steps after that with
# 'countable'-variables
for game in todos:
    Game[counter] = game
    #games.append(game)
    for team in Game[counter]:
        #Safe the date
        Date[counter] = Game[counter]['MatchDateTime']
        #Safe Teamnames, by going through the list
        Team1 = Game[counter]['Team1']
        Hometeam[counter] = Team1['TeamName']
        Team2 = Game[counter]['Team2']
        Awayteam[counter] = Team2['TeamName']
        #Safe scored goals by team, by going through the list
        Matchresults = Game[counter]['MatchResults']
        Result = Matchresults[0]
        GoalsHome[counter] = Result['PointsTeam1']
        GoalsAway[counter] = Result['PointsTeam2']
        
    counter +=1
    
print(Date[0])
print(Hometeam[0])
print(Awayteam[0])
print(GoalsHome[0])
print(GoalsAway[0])
    #counter += 1
    #print(counter)
print(Game1['MatchID'])



#Game1 = todos[1]  #safe Game one from list
#Game1['MatchID']  #get GameID from that game
# Out:
# 2019-04-20T15:30:00
# FC Bayern
# Werder Bremen
# 1
# 0
# 51383

# %%
todos[5]
# Out:
# {'MatchID': 51382,
#  'MatchDateTime': '2019-04-20T20:30:00',
#  'TimeZoneID': 'W. Europe Standard Time',
#  'LeagueId': 4276,
#  'LeagueName': '1. Fußball-Bundesliga 2018/2019',
#  'MatchDateTimeUTC': '2019-04-20T18:30:00Z',
#  'Group': {'GroupName': '30. Spieltag', 'GroupOrderID': 30, 'GroupID': 31804},
#  'Team1': {'TeamId': 9,
#   'TeamName': 'FC Schalke 04',
#   'ShortName': 'Schalke',
#   'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6d/FC_Schalke_04_Logo.svg/1024px-FC_Schalke_04_Logo.svg.png',
#   'TeamGroupName': None},
#  'Team2': {'TeamId': 123,
#   'TeamName': 'TSG 1899 Hoffenheim',
#   'ShortName': 'Hoffenheim',
#   'TeamIconUrl': 'https://upload.wikimedia.org/wikipedia/commons/6/64/TSG_Logo-Standard_4c.png',
#   'TeamGroupName': None},
#  'LastUpdateDateTime': '2019-04-20T22:20:57.353',
#  'MatchIsFinished': True,
#  'MatchResults': [{'ResultID': 86860,
#    'ResultName': 'Endergebnis',
#    'PointsTeam1': 2,
#    'PointsTeam2': 5,
#    'ResultOrderID': 2,
#    'ResultTypeID': 2,
#    'ResultDescription': 'Ergebnis nach Ende der offiziellen Spielzeit'},
#   {'ResultID': 86861,
#    'ResultName': 'Halbzeit',
#    'PointsTeam1': 0,
#    'PointsTeam2': 2,
#    'ResultOrderID': 1,
#    'ResultTypeID': 1,
#    'ResultDescription': 'Zwischenstand zur Halbzeit'}],
#  'Goals': [{'GoalID': 77135,
#    'ScoreTeam1': 0,
#    'ScoreTeam2': 1,
#    'MatchMinute': 25,
#    'GoalGetterID': 7180,
#    'GoalGetterName': 'Belfodil',
#    'IsPenalty': False,
#    'IsOwnGoal': False,
#    'IsOvertime': False,
#    'Comment': None},
#   {'GoalID': 77136,
#    'ScoreTeam1': 0,
#    'ScoreTeam2': 2,
#    'MatchMinute': 45,
#    'GoalGetterID': 16104,
#    'GoalGetterName': 'Andrej Kramaric',
#    'IsPenalty': False,
#    'IsOwnGoal': False,
#    'IsOvertime': False,
#    'Comment': None},
#   {'GoalID': 77137,
#    'ScoreTeam1': 1,
#    'ScoreTeam2': 2,
#    'MatchMinute': 60,
#    'GoalGetterID': 14694,
#    'GoalGetterName': 'Caligiuri, Daniel',
#    'IsPenalty': True,
#    'IsOwnGoal': False,
#    'IsOvertime': False,
#    'Comment': None},
#   {'GoalID': 77138,
#    'ScoreTeam1': 1,
#    'ScoreTeam2': 3,
#    'MatchMinute': 65,
#    'GoalGetterID': 15841,
#    'GoalGetterName': 'Szalai, Adam',
#    'IsPenalty': False,
#    'IsOwnGoal': False,
#    'IsOvertime': False,
#    'Comment': None},
#   {'GoalID': 77139,
#    'ScoreTeam1': 1,
#    'ScoreTeam2': 4,
#    'MatchMinute': 73,
#    'GoalGetterID': 16216,
#    'GoalGetterName': 'Nadiem Amiri',
#    'IsPenalty': False,
#    'IsOwnGoal': False,
#    'IsOvertime': False,
#    'Comment': None},
#   {'GoalID': 77140,
#    'ScoreTeam1': 1,
#    'ScoreTeam2': 5,
#    'MatchMinute': 80,
#    'GoalGetterID': 7180,
#    'GoalGetterName': 'Belfodil',
#    'IsPenalty': False,
#    'IsOwnGoal': False,
#    'IsOvertime': False,
#    'Comment': None},
#   {'GoalID': 77141,
#    'ScoreTeam1': 2,
#    'ScoreTeam2': 5,
#    'MatchMinute': 89,
#    'GoalGetterID': 15352,
#    'GoalGetterName': 'Burgstaller, Guido',
#    'IsPenalty': False,
#    'IsOwnGoal': False,
#    'IsOvertime': False,
#    'Comment': None}],
#  'Location': None,
#  'NumberOfViewers': None}
